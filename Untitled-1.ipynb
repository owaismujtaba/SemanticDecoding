# %%
import mne
import numpy as np
filepath = 'C:\ImaginationPerceptionDataset\DataSet\perceptionImaginationEEG\preprocessed\sub-08\ses-03\eeg\sub8_sess3_50_ica_eeg.fif'

# %%
data = mne.io.read_raw_fif(filepath, preload=True, verbose=False)

# %%
anot = data.annotations
for item in anot:
    print(item)
# Out:
# OrderedDict([('onset', 0.0), ('duration', 0.0), ('description', '0, Impedance'), ('orig_time', None)])
# OrderedDict([('onset', 95.234375), ('duration', 0.0), ('description', '0, start_baseline###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 107.205078), ('duration', 0.0), ('description', '0, end_baseline###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 108.522461), ('duration', 0.0), ('description', '0, Perception_t_flower_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 111.974609), ('duration', 0.0), ('description', '0, Imagination_t_flower_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 116.719727), ('duration', 0.0), ('description', '0, Perception_t_penguin_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 120.192383), ('duration', 0.0), ('description', '0, Imagination_t_penguin_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 124.951172), ('duration', 0.0), ('description', '0, Perception_t_penguin_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 128.433594), ('duration', 0.0), ('description', '0, Imagination_t_penguin_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 133.179688), ('duration', 0.0), ('description', '0, Perception_t_flower_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 136.665039), ('duration', 0.0), ('description', '0, Imagination_t_flower_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 141.410156), ('duration', 0.0), ('description', '0, Perception_t_flower_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 144.889648), ('duration', 0.0), ('description', '0, Imagination_t_flower_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 150.71875), ('duration', 0.0), ('description', '0, Perception_image_guitar_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 154.155273), ('duration', 0.0), ('description', '0, Imagination_image_guitar_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 158.933594), ('duration', 0.0), ('description', '0, Perception_image_guitar_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 162.396484), ('duration', 0.0), ('description', '0, Imagination_image_guitar_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 167.151367), ('duration', 0.0), ('description', '0, Perception_image_guitar_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 170.643555), ('duration', 0.0), ('description', '0, Imagination_image_guitar_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 175.421875), ('duration', 0.0), ('description', '0, Perception_image_flower_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 178.894531), ('duration', 0.0), ('description', '0, Imagination_image_flower_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 183.682617), ('duration', 0.0), ('description', '0, Perception_image_flower_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 187.151367), ('duration', 0.0), ('description', '0, Imagination_image_flower_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 192.788086), ('duration', 0.0), ('description', '0, Perceptiona_guitar_normal_18###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 195.712891), ('duration', 0.0), ('description', '0, Imagination_a_guitar_normal_18###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 200.693359), ('duration', 0.0), ('description', '0, Perceptiona_flower_normal_16###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 203.700195), ('duration', 0.0), ('description', '0, Imagination_a_flower_normal_16###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 208.696289), ('duration', 0.0), ('description', '0, Perceptiona_guitar_low_10###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 211.700195), ('duration', 0.0), ('description', '0, Imagination_a_guitar_low_10###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 216.682617), ('duration', 0.0), ('description', '0, Perceptiona_flower_low_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 219.686523), ('duration', 0.0), ('description', '0, Imagination_a_flower_low_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 224.671875), ('duration', 0.0), ('description', '0, Perceptiona_guitar_normal_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 227.679688), ('duration', 0.0), ('description', '0, Imagination_a_guitar_normal_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 233.974609), ('duration', 0.0), ('description', '0, Perception_t_guitar_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 237.433594), ('duration', 0.0), ('description', '0, Imagination_t_guitar_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 242.19043), ('duration', 0.0), ('description', '0, Perception_t_flower_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 245.675781), ('duration', 0.0), ('description', '0, Imagination_t_flower_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 250.4375), ('duration', 0.0), ('description', '0, Perception_t_penguin_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 253.924805), ('duration', 0.0), ('description', '0, Imagination_t_penguin_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 258.664062), ('duration', 0.0), ('description', '0, Perception_t_guitar_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 262.144531), ('duration', 0.0), ('description', '0, Imagination_t_guitar_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 266.889648), ('duration', 0.0), ('description', '0, Perception_t_flower_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 270.368164), ('duration', 0.0), ('description', '0, Imagination_t_flower_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 275.963867), ('duration', 0.0), ('description', '0, Perceptiona_guitar_normal_19###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 278.876953), ('duration', 0.0), ('description', '0, Imagination_a_guitar_normal_19###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 283.862305), ('duration', 0.0), ('description', '0, Perceptiona_penguin_normal_16###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 286.860352), ('duration', 0.0), ('description', '0, Imagination_a_penguin_normal_16###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 291.847656), ('duration', 0.0), ('description', '0, Perceptiona_flower_normal_24###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 294.848633), ('duration', 0.0), ('description', '0, Imagination_a_flower_normal_24###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 299.836914), ('duration', 0.0), ('description', '0, Perceptiona_guitar_high_14###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 302.832031), ('duration', 0.0), ('description', '0, Imagination_a_guitar_high_14###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 307.821289), ('duration', 0.0), ('description', '0, Perceptiona_penguin_high_12###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 310.818359), ('duration', 0.0), ('description', '0, Imagination_a_penguin_high_12###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 317.111328), ('duration', 0.0), ('description', '0, Perception_image_penguin_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 320.551758), ('duration', 0.0), ('description', '0, Imagination_image_penguin_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 325.317383), ('duration', 0.0), ('description', '0, Perception_image_guitar_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 328.800781), ('duration', 0.0), ('description', '0, Imagination_image_guitar_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 333.578125), ('duration', 0.0), ('description', '0, Perception_image_flower_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 337.056641), ('duration', 0.0), ('description', '0, Imagination_image_flower_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 341.823242), ('duration', 0.0), ('description', '0, Perception_image_guitar_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 345.310547), ('duration', 0.0), ('description', '0, Imagination_image_guitar_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 350.070312), ('duration', 0.0), ('description', '0, Perception_image_penguin_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 353.542969), ('duration', 0.0), ('description', '0, Imagination_image_penguin_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 359.364258), ('duration', 0.0), ('description', '0, Perception_image_guitar_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 362.833008), ('duration', 0.0), ('description', '0, Imagination_image_guitar_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 367.616211), ('duration', 0.0), ('description', '0, Perception_image_flower_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 371.083984), ('duration', 0.0), ('description', '0, Imagination_image_flower_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 375.841797), ('duration', 0.0), ('description', '0, Perception_image_guitar_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 379.339844), ('duration', 0.0), ('description', '0, Imagination_image_guitar_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 384.089844), ('duration', 0.0), ('description', '0, Perception_image_guitar_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 387.571289), ('duration', 0.0), ('description', '0, Imagination_image_guitar_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 392.362305), ('duration', 0.0), ('description', '0, Perception_image_flower_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 395.842773), ('duration', 0.0), ('description', '0, Imagination_image_flower_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 401.489258), ('duration', 0.0), ('description', '0, Perceptiona_guitar_normal_22###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 404.388672), ('duration', 0.0), ('description', '0, Imagination_a_guitar_normal_22###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 409.375), ('duration', 0.0), ('description', '0, Perceptiona_guitar_low_10###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 412.37207), ('duration', 0.0), ('description', '0, Imagination_a_guitar_low_10###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 417.360352), ('duration', 0.0), ('description', '0, Perceptiona_flower_normal_12###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 420.356445), ('duration', 0.0), ('description', '0, Imagination_a_flower_normal_12###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 425.349609), ('duration', 0.0), ('description', '0, Perceptiona_flower_normal_17###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 428.34668), ('duration', 0.0), ('description', '0, Imagination_a_flower_normal_17###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 433.330078), ('duration', 0.0), ('description', '0, Perceptiona_guitar_normal_11###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 436.333008), ('duration', 0.0), ('description', '0, Imagination_a_guitar_normal_11###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 442.610352), ('duration', 0.0), ('description', '0, Perception_t_flower_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 446.075195), ('duration', 0.0), ('description', '0, Imagination_t_flower_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 450.832031), ('duration', 0.0), ('description', '0, Perception_t_penguin_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 454.316406), ('duration', 0.0), ('description', '0, Imagination_t_penguin_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 459.069336), ('duration', 0.0), ('description', '0, Perception_t_penguin_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 462.548828), ('duration', 0.0), ('description', '0, Imagination_t_penguin_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 467.321289), ('duration', 0.0), ('description', '0, Perception_t_flower_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 470.806641), ('duration', 0.0), ('description', '0, Imagination_t_flower_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 475.561523), ('duration', 0.0), ('description', '0, Perception_t_flower_2###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 479.057617), ('duration', 0.0), ('description', '0, Imagination_t_flower_2###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 591.762695), ('duration', 0.0), ('description', '0, start_baseline###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 603.748047), ('duration', 0.0), ('description', '0, end_baseline###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 605.056641), ('duration', 0.0), ('description', '0, Perception_t_flower_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 608.517578), ('duration', 0.0), ('description', '0, Imagination_t_flower_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 613.261719), ('duration', 0.0), ('description', '0, Perception_t_guitar_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 616.742188), ('duration', 0.0), ('description', '0, Imagination_t_guitar_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 621.480469), ('duration', 0.0), ('description', '0, Perception_t_flower_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 624.974609), ('duration', 0.0), ('description', '0, Imagination_t_flower_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 629.716797), ('duration', 0.0), ('description', '0, Perception_t_flower_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 633.198242), ('duration', 0.0), ('description', '0, Imagination_t_flower_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 637.933594), ('duration', 0.0), ('description', '0, Perception_t_guitar_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 641.414062), ('duration', 0.0), ('description', '0, Imagination_t_guitar_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 647.219727), ('duration', 0.0), ('description', '0, Perception_image_guitar_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 650.670898), ('duration', 0.0), ('description', '0, Imagination_image_guitar_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 655.444336), ('duration', 0.0), ('description', '0, Perception_image_guitar_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 658.919922), ('duration', 0.0), ('description', '0, Imagination_image_guitar_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 663.685547), ('duration', 0.0), ('description', '0, Perception_image_penguin_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 667.168945), ('duration', 0.0), ('description', '0, Imagination_image_penguin_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 671.936523), ('duration', 0.0), ('description', '0, Perception_image_guitar_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 675.425781), ('duration', 0.0), ('description', '0, Imagination_image_guitar_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 680.186523), ('duration', 0.0), ('description', '0, Perception_image_penguin_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 683.65918), ('duration', 0.0), ('description', '0, Imagination_image_penguin_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 689.301758), ('duration', 0.0), ('description', '0, Perceptiona_penguin_high_6###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 692.203125), ('duration', 0.0), ('description', '0, Imagination_a_penguin_high_6###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 697.192383), ('duration', 0.0), ('description', '0, Perceptiona_guitar_high_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 700.188477), ('duration', 0.0), ('description', '0, Imagination_a_guitar_high_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 705.175781), ('duration', 0.0), ('description', '0, Perceptiona_penguin_high_12###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 708.177734), ('duration', 0.0), ('description', '0, Imagination_a_penguin_high_12###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 713.166992), ('duration', 0.0), ('description', '0, Perceptiona_guitar_high_25###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 716.163086), ('duration', 0.0), ('description', '0, Imagination_a_guitar_high_25###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 721.149414), ('duration', 0.0), ('description', '0, Perceptiona_guitar_normal_9###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 724.145508), ('duration', 0.0), ('description', '0, Imagination_a_guitar_normal_9###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 730.229492), ('duration', 0.0), ('description', '0, Perceptiona_penguin_high_10###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 733.152344), ('duration', 0.0), ('description', '0, Imagination_a_penguin_high_10###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 738.139648), ('duration', 0.0), ('description', '0, Perceptiona_penguin_normal_1 ###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 741.137695), ('duration', 0.0), ('description', '0, Imagination_a_penguin_normal_1 ###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 746.125977), ('duration', 0.0), ('description', '0, Perceptiona_penguin_normal_19###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 749.121094), ('duration', 0.0), ('description', '0, Imagination_a_penguin_normal_19###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 754.115234), ('duration', 0.0), ('description', '0, Perceptiona_guitar_high_11###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 757.110352), ('duration', 0.0), ('description', '0, Imagination_a_guitar_high_11###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 762.098633), ('duration', 0.0), ('description', '0, Perceptiona_flower_normal_23###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 765.094727), ('duration', 0.0), ('description', '0, Imagination_a_flower_normal_23###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 771.378906), ('duration', 0.0), ('description', '0, Perception_t_guitar_2###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 774.826172), ('duration', 0.0), ('description', '0, Imagination_t_guitar_2###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 779.580078), ('duration', 0.0), ('description', '0, Perception_t_guitar_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 783.043945), ('duration', 0.0), ('description', '0, Imagination_t_guitar_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 787.790039), ('duration', 0.0), ('description', '0, Perception_t_guitar_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 791.285156), ('duration', 0.0), ('description', '0, Imagination_t_guitar_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 796.038086), ('duration', 0.0), ('description', '0, Perception_t_flower_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 799.516602), ('duration', 0.0), ('description', '0, Imagination_t_flower_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 804.290039), ('duration', 0.0), ('description', '0, Perception_t_penguin_2###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 807.773438), ('duration', 0.0), ('description', '0, Imagination_t_penguin_2###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 813.571289), ('duration', 0.0), ('description', '0, Perception_image_flower_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 817.022461), ('duration', 0.0), ('description', '0, Imagination_image_flower_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 821.786133), ('duration', 0.0), ('description', '0, Perception_image_penguin_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 825.279297), ('duration', 0.0), ('description', '0, Imagination_image_penguin_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 830.030273), ('duration', 0.0), ('description', '0, Perception_image_penguin_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 833.510742), ('duration', 0.0), ('description', '0, Imagination_image_penguin_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 838.277344), ('duration', 0.0), ('description', '0, Perception_image_penguin_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 841.769531), ('duration', 0.0), ('description', '0, Imagination_image_penguin_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 846.552734), ('duration', 0.0), ('description', '0, Perception_image_guitar_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 850.038086), ('duration', 0.0), ('description', '0, Imagination_image_guitar_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 855.672852), ('duration', 0.0), ('description', '0, Perceptiona_guitar_low_17###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 858.599609), ('duration', 0.0), ('description', '0, Imagination_a_guitar_low_17###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 863.583008), ('duration', 0.0), ('description', '0, Perceptiona_guitar_normal_12###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 866.583008), ('duration', 0.0), ('description', '0, Imagination_a_guitar_normal_12###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 871.567383), ('duration', 0.0), ('description', '0, Perceptiona_penguin_normal_6###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 874.573242), ('duration', 0.0), ('description', '0, Imagination_a_penguin_normal_6###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 879.577148), ('duration', 0.0), ('description', '0, Perceptiona_flower_normal_21###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 882.572266), ('duration', 0.0), ('description', '0, Imagination_a_flower_normal_21###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 887.560547), ('duration', 0.0), ('description', '0, Perceptiona_flower_low_10###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 890.557617), ('duration', 0.0), ('description', '0, Imagination_a_flower_low_10###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 896.848633), ('duration', 0.0), ('description', '0, Perception_image_penguin_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 900.288086), ('duration', 0.0), ('description', '0, Imagination_image_penguin_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 905.047852), ('duration', 0.0), ('description', '0, Perception_image_guitar_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 908.521484), ('duration', 0.0), ('description', '0, Imagination_image_guitar_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 913.306641), ('duration', 0.0), ('description', '0, Perception_image_guitar_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 916.792969), ('duration', 0.0), ('description', '0, Imagination_image_guitar_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 921.580078), ('duration', 0.0), ('description', '0, Perception_image_flower_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 925.043945), ('duration', 0.0), ('description', '0, Imagination_image_flower_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 929.811523), ('duration', 0.0), ('description', '0, Perception_image_flower_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 933.300781), ('duration', 0.0), ('description', '0, Imagination_image_flower_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 939.130859), ('duration', 0.0), ('description', '0, Perception_t_flower_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 942.583984), ('duration', 0.0), ('description', '0, Imagination_t_flower_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 947.347656), ('duration', 0.0), ('description', '0, Perception_t_flower_2###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 950.84082), ('duration', 0.0), ('description', '0, Imagination_t_flower_2###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 955.583008), ('duration', 0.0), ('description', '0, Perception_t_penguin_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 959.072266), ('duration', 0.0), ('description', '0, Imagination_t_penguin_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 963.813477), ('duration', 0.0), ('description', '0, Perception_t_guitar_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 967.291016), ('duration', 0.0), ('description', '0, Imagination_t_guitar_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 972.056641), ('duration', 0.0), ('description', '0, Perception_t_penguin_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 975.548828), ('duration', 0.0), ('description', '0, Imagination_t_penguin_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1072.870117), ('duration', 0.0), ('description', '0, start_baseline###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1084.839844), ('duration', 0.0), ('description', '0, end_baseline###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1086.164062), ('duration', 0.0), ('description', '0, Perception_image_penguin_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1089.601562), ('duration', 0.0), ('description', '0, Imagination_image_penguin_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1094.364258), ('duration', 0.0), ('description', '0, Perception_image_guitar_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1097.861328), ('duration', 0.0), ('description', '0, Imagination_image_guitar_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1102.639648), ('duration', 0.0), ('description', '0, Perception_image_flower_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1106.091797), ('duration', 0.0), ('description', '0, Imagination_image_flower_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1110.875977), ('duration', 0.0), ('description', '0, Perception_image_penguin_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1114.348633), ('duration', 0.0), ('description', '0, Imagination_image_penguin_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1119.108398), ('duration', 0.0), ('description', '0, Perception_image_guitar_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1122.602539), ('duration', 0.0), ('description', '0, Imagination_image_guitar_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1128.429688), ('duration', 0.0), ('description', '0, Perception_t_flower_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1131.884766), ('duration', 0.0), ('description', '0, Imagination_t_flower_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1136.632812), ('duration', 0.0), ('description', '0, Perception_t_guitar_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1140.125977), ('duration', 0.0), ('description', '0, Imagination_t_guitar_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1144.875977), ('duration', 0.0), ('description', '0, Perception_t_flower_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1148.357422), ('duration', 0.0), ('description', '0, Imagination_t_flower_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1153.104492), ('duration', 0.0), ('description', '0, Perception_t_guitar_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1156.597656), ('duration', 0.0), ('description', '0, Imagination_t_guitar_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1161.345703), ('duration', 0.0), ('description', '0, Perception_t_penguin_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1164.832031), ('duration', 0.0), ('description', '0, Imagination_t_penguin_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1170.4375), ('duration', 0.0), ('description', '0, Perceptiona_penguin_normal_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1173.344727), ('duration', 0.0), ('description', '0, Imagination_a_penguin_normal_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1178.348633), ('duration', 0.0), ('description', '0, Perceptionaudio_a_guitar_normal_10###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1181.34375), ('duration', 0.0), ('description', '0, Imagination_audio_a_guitar_normal_10###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1186.332031), ('duration', 0.0), ('description', '0, Perceptiona_penguin_normal_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1189.328125), ('duration', 0.0), ('description', '0, Imagination_a_penguin_normal_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1194.314453), ('duration', 0.0), ('description', '0, Perceptiona_flower_high_10###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1197.321289), ('duration', 0.0), ('description', '0, Imagination_a_flower_high_10###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1202.304688), ('duration', 0.0), ('description', '0, Perceptiona_guitar_normal_19###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1205.305664), ('duration', 0.0), ('description', '0, Imagination_a_guitar_normal_19###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1211.383789), ('duration', 0.0), ('description', '0, Perceptiona_flower_low_25###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1214.303711), ('duration', 0.0), ('description', '0, Imagination_a_flower_low_25###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1219.291016), ('duration', 0.0), ('description', '0, Perceptiona_flower_normal_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1222.297852), ('duration', 0.0), ('description', '0, Imagination_a_flower_normal_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1227.299805), ('duration', 0.0), ('description', '0, Perceptiona_guitar_normal_10###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1230.295898), ('duration', 0.0), ('description', '0, Imagination_a_guitar_normal_10###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1235.28125), ('duration', 0.0), ('description', '0, Perceptiona_penguin_high_25###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1238.27832), ('duration', 0.0), ('description', '0, Imagination_a_penguin_high_25###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1243.266602), ('duration', 0.0), ('description', '0, Perceptiona_penguin_normal_16###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1246.269531), ('duration', 0.0), ('description', '0, Imagination_a_penguin_normal_16###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1252.548828), ('duration', 0.0), ('description', '0, Perception_t_guitar_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1255.998047), ('duration', 0.0), ('description', '0, Imagination_t_guitar_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1260.74707), ('duration', 0.0), ('description', '0, Perception_t_penguin_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1264.231445), ('duration', 0.0), ('description', '0, Imagination_t_penguin_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1268.977539), ('duration', 0.0), ('description', '0, Perception_t_penguin_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1272.474609), ('duration', 0.0), ('description', '0, Imagination_t_penguin_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1277.212891), ('duration', 0.0), ('description', '0, Perception_t_flower_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1280.705078), ('duration', 0.0), ('description', '0, Imagination_t_flower_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1285.451172), ('duration', 0.0), ('description', '0, Perception_t_guitar_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1288.945312), ('duration', 0.0), ('description', '0, Imagination_t_guitar_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1294.759766), ('duration', 0.0), ('description', '0, Perception_image_guitar_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1298.198242), ('duration', 0.0), ('description', '0, Imagination_image_guitar_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1302.955078), ('duration', 0.0), ('description', '0, Perception_image_penguin_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1306.433594), ('duration', 0.0), ('description', '0, Imagination_image_penguin_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1311.192383), ('duration', 0.0), ('description', '0, Perception_image_flower_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1314.680664), ('duration', 0.0), ('description', '0, Imagination_image_flower_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1319.454102), ('duration', 0.0), ('description', '0, Perception_image_penguin_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1322.938477), ('duration', 0.0), ('description', '0, Imagination_image_penguin_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1327.714844), ('duration', 0.0), ('description', '0, Perception_image_flower_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1331.188477), ('duration', 0.0), ('description', '0, Imagination_image_flower_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1337.035156), ('duration', 0.0), ('description', '0, Perception_t_penguin_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1340.493164), ('duration', 0.0), ('description', '0, Imagination_t_penguin_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1345.25), ('duration', 0.0), ('description', '0, Perception_t_penguin_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1348.734375), ('duration', 0.0), ('description', '0, Imagination_t_penguin_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1353.490234), ('duration', 0.0), ('description', '0, Perception_t_flower_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1356.983398), ('duration', 0.0), ('description', '0, Imagination_t_flower_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1361.728516), ('duration', 0.0), ('description', '0, Perception_t_guitar_2###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1365.217773), ('duration', 0.0), ('description', '0, Imagination_t_guitar_2###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1369.964844), ('duration', 0.0), ('description', '0, Perception_t_flower_2###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1373.458984), ('duration', 0.0), ('description', '0, Imagination_t_flower_2###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1379.291992), ('duration', 0.0), ('description', '0, Perception_image_guitar_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1382.72168), ('duration', 0.0), ('description', '0, Imagination_image_guitar_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1387.496094), ('duration', 0.0), ('description', '0, Perception_image_flower_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1390.979492), ('duration', 0.0), ('description', '0, Imagination_image_flower_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1395.71875), ('duration', 0.0), ('description', '0, Perception_image_penguin_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1399.213867), ('duration', 0.0), ('description', '0, Imagination_image_penguin_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1403.984375), ('duration', 0.0), ('description', '0, Perception_image_guitar_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1407.47168), ('duration', 0.0), ('description', '0, Imagination_image_guitar_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1412.230469), ('duration', 0.0), ('description', '0, Perception_image_flower_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1415.72168), ('duration', 0.0), ('description', '0, Imagination_image_flower_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1421.374023), ('duration', 0.0), ('description', '0, Perceptiona_flower_high_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1424.293945), ('duration', 0.0), ('description', '0, Imagination_a_flower_high_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1429.283203), ('duration', 0.0), ('description', '0, Perceptiona_penguin_normal_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1432.288086), ('duration', 0.0), ('description', '0, Imagination_a_penguin_normal_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1437.293945), ('duration', 0.0), ('description', '0, Perceptiona_guitar_low_19###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1440.28418), ('duration', 0.0), ('description', '0, Imagination_a_guitar_low_19###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1445.269531), ('duration', 0.0), ('description', '0, Perceptiona_guitar_normal_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1448.275391), ('duration', 0.0), ('description', '0, Imagination_a_guitar_normal_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1453.260742), ('duration', 0.0), ('description', '0, Perceptiona_flower_normal_11###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1456.258789), ('duration', 0.0), ('description', '0, Imagination_a_flower_normal_11###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1612.888672), ('duration', 0.0), ('description', '0, start_baseline###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1624.858398), ('duration', 0.0), ('description', '0, end_baseline###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1626.172852), ('duration', 0.0), ('description', '0, Perception_image_penguin_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1629.62793), ('duration', 0.0), ('description', '0, Imagination_image_penguin_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1634.395508), ('duration', 0.0), ('description', '0, Perception_image_penguin_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1637.884766), ('duration', 0.0), ('description', '0, Imagination_image_penguin_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1642.637695), ('duration', 0.0), ('description', '0, Perception_image_guitar_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1646.120117), ('duration', 0.0), ('description', '0, Imagination_image_guitar_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1650.885742), ('duration', 0.0), ('description', '0, Perception_image_penguin_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1654.369141), ('duration', 0.0), ('description', '0, Imagination_image_penguin_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1659.145508), ('duration', 0.0), ('description', '0, Perception_image_penguin_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1662.62793), ('duration', 0.0), ('description', '0, Imagination_image_penguin_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1668.461914), ('duration', 0.0), ('description', '0, Perception_t_guitar_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1671.922852), ('duration', 0.0), ('description', '0, Imagination_t_guitar_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1676.677734), ('duration', 0.0), ('description', '0, Perception_t_guitar_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1680.164062), ('duration', 0.0), ('description', '0, Imagination_t_guitar_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1684.920898), ('duration', 0.0), ('description', '0, Perception_t_guitar_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1688.397461), ('duration', 0.0), ('description', '0, Imagination_t_guitar_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1693.150391), ('duration', 0.0), ('description', '0, Perception_t_guitar_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1696.62207), ('duration', 0.0), ('description', '0, Imagination_t_guitar_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1701.381836), ('duration', 0.0), ('description', '0, Perception_t_flower_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1704.854492), ('duration', 0.0), ('description', '0, Imagination_t_flower_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1710.455078), ('duration', 0.0), ('description', '0, Perceptiona_penguin_normal_15###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1713.369141), ('duration', 0.0), ('description', '0, Imagination_a_penguin_normal_15###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1718.349609), ('duration', 0.0), ('description', '0, Perceptiona_penguin_high_10###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1721.353516), ('duration', 0.0), ('description', '0, Imagination_a_penguin_high_10###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1726.356445), ('duration', 0.0), ('description', '0, Perceptiona_penguin_high_9###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1729.352539), ('duration', 0.0), ('description', '0, Imagination_a_penguin_high_9###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1734.339844), ('duration', 0.0), ('description', '0, Perceptiona_guitar_low_25###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1737.341797), ('duration', 0.0), ('description', '0, Imagination_a_guitar_low_25###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1742.331055), ('duration', 0.0), ('description', '0, Perceptiona_penguin_low_15###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1745.329102), ('duration', 0.0), ('description', '0, Imagination_a_penguin_low_15###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1751.405273), ('duration', 0.0), ('description', '0, Perceptiona_flower_normal_19###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1754.334961), ('duration', 0.0), ('description', '0, Imagination_a_flower_normal_19###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1759.313477), ('duration', 0.0), ('description', '0, Perceptiona_penguin_normal_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1762.317383), ('duration', 0.0), ('description', '0, Imagination_a_penguin_normal_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1767.303711), ('duration', 0.0), ('description', '0, Perceptiona_flower_normal_6###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1770.298828), ('duration', 0.0), ('description', '0, Imagination_a_flower_normal_6###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1775.289062), ('duration', 0.0), ('description', '0, Perceptiona_guitar_normal_22###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1778.291992), ('duration', 0.0), ('description', '0, Imagination_a_guitar_normal_22###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1783.279297), ('duration', 0.0), ('description', '0, Perceptiona_flower_normal_24###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1786.274414), ('duration', 0.0), ('description', '0, Imagination_a_flower_normal_24###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1792.551758), ('duration', 0.0), ('description', '0, Perception_t_penguin_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1796.005859), ('duration', 0.0), ('description', '0, Imagination_t_penguin_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1800.749023), ('duration', 0.0), ('description', '0, Perception_t_guitar_2###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1804.236328), ('duration', 0.0), ('description', '0, Imagination_t_guitar_2###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1809.007812), ('duration', 0.0), ('description', '0, Perception_t_penguin_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1812.477539), ('duration', 0.0), ('description', '0, Imagination_t_penguin_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1817.235352), ('duration', 0.0), ('description', '0, Perception_t_penguin_2###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1820.711914), ('duration', 0.0), ('description', '0, Imagination_t_penguin_2###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1825.460938), ('duration', 0.0), ('description', '0, Perception_t_flower_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1828.951172), ('duration', 0.0), ('description', '0, Imagination_t_flower_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1834.780273), ('duration', 0.0), ('description', '0, Perception_image_flower_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1838.223633), ('duration', 0.0), ('description', '0, Imagination_image_flower_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1842.974609), ('duration', 0.0), ('description', '0, Perception_image_flower_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1846.457031), ('duration', 0.0), ('description', '0, Imagination_image_flower_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1851.21875), ('duration', 0.0), ('description', '0, Perception_image_flower_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 1854.691406), ('duration', 0.0), ('description', '0, Imagination_image_flower_c###my_stream_name'), ('orig_time', None)])
# ...
# OrderedDict([('onset', 4084.085938), ('duration', 0.0), ('description', '0, Perceptiona_penguin_high_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4087.088867), ('duration', 0.0), ('description', '0, Imagination_a_penguin_high_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4092.068359), ('duration', 0.0), ('description', '0, Perceptiona_guitar_low_25###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4095.072266), ('duration', 0.0), ('description', '0, Imagination_a_guitar_low_25###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4100.064453), ('duration', 0.0), ('description', '0, Perceptiona_penguin_low_10###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4103.054688), ('duration', 0.0), ('description', '0, Imagination_a_penguin_low_10###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4108.044922), ('duration', 0.0), ('description', '0, Perceptiona_guitar_normal_25###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4111.046875), ('duration', 0.0), ('description', '0, Imagination_a_guitar_normal_25###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4117.325195), ('duration', 0.0), ('description', '0, Perception_t_guitar_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4120.771484), ('duration', 0.0), ('description', '0, Imagination_t_guitar_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4125.525391), ('duration', 0.0), ('description', '0, Perception_t_flower_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4129.012695), ('duration', 0.0), ('description', '0, Imagination_t_flower_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4133.780273), ('duration', 0.0), ('description', '0, Perception_t_guitar_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4137.261719), ('duration', 0.0), ('description', '0, Imagination_t_guitar_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4142.018555), ('duration', 0.0), ('description', '0, Perception_t_flower_2###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4145.501953), ('duration', 0.0), ('description', '0, Imagination_t_flower_2###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4150.266602), ('duration', 0.0), ('description', '0, Perception_t_guitar_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4153.750977), ('duration', 0.0), ('description', '0, Imagination_t_guitar_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4165.104492), ('duration', 0.0), ('description', '0, start_baseline###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4177.089844), ('duration', 0.0), ('description', '0, end_baseline###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4178.412109), ('duration', 0.0), ('description', '0, Perception_image_guitar_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4181.858398), ('duration', 0.0), ('description', '0, Imagination_image_guitar_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4186.634766), ('duration', 0.0), ('description', '0, Perception_image_guitar_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4190.115234), ('duration', 0.0), ('description', '0, Imagination_image_guitar_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4194.876953), ('duration', 0.0), ('description', '0, Perception_image_flower_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4198.349609), ('duration', 0.0), ('description', '0, Imagination_image_flower_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4203.116211), ('duration', 0.0), ('description', '0, Perception_image_penguin_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4206.598633), ('duration', 0.0), ('description', '0, Imagination_image_penguin_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4211.362305), ('duration', 0.0), ('description', '0, Perception_image_penguin_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4214.854492), ('duration', 0.0), ('description', '0, Imagination_image_penguin_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4220.500977), ('duration', 0.0), ('description', '0, Perceptiona_flower_normal_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4223.40332), ('duration', 0.0), ('description', '0, Imagination_a_flower_normal_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4228.402344), ('duration', 0.0), ('description', '0, Perceptiona_guitar_low_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4231.404297), ('duration', 0.0), ('description', '0, Imagination_a_guitar_low_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4236.383789), ('duration', 0.0), ('description', '0, Perceptiona_penguin_low_19###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4239.388672), ('duration', 0.0), ('description', '0, Imagination_a_penguin_low_19###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4244.376953), ('duration', 0.0), ('description', '0, Perceptiona_guitar_low_17###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4247.37207), ('duration', 0.0), ('description', '0, Imagination_a_guitar_low_17###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4252.359375), ('duration', 0.0), ('description', '0, Perceptiona_penguin_low_6###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4255.362305), ('duration', 0.0), ('description', '0, Imagination_a_penguin_low_6###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4261.647461), ('duration', 0.0), ('description', '0, Perception_t_guitar_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4265.087891), ('duration', 0.0), ('description', '0, Imagination_t_guitar_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4269.838867), ('duration', 0.0), ('description', '0, Perception_t_flower_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4273.327148), ('duration', 0.0), ('description', '0, Imagination_t_flower_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4278.083008), ('duration', 0.0), ('description', '0, Perception_t_penguin_2###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4281.561523), ('duration', 0.0), ('description', '0, Imagination_t_penguin_2###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4286.305664), ('duration', 0.0), ('description', '0, Perception_t_guitar_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4289.801758), ('duration', 0.0), ('description', '0, Imagination_t_guitar_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4294.546875), ('duration', 0.0), ('description', '0, Perception_t_flower_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4298.036133), ('duration', 0.0), ('description', '0, Imagination_t_flower_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4303.858398), ('duration', 0.0), ('description', '0, Perception_image_flower_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4307.308594), ('duration', 0.0), ('description', '0, Imagination_image_flower_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4312.071289), ('duration', 0.0), ('description', '0, Perception_image_penguin_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4315.557617), ('duration', 0.0), ('description', '0, Imagination_image_penguin_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4320.324219), ('duration', 0.0), ('description', '0, Perception_image_penguin_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4323.805664), ('duration', 0.0), ('description', '0, Imagination_image_penguin_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4328.571289), ('duration', 0.0), ('description', '0, Perception_image_penguin_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4332.043945), ('duration', 0.0), ('description', '0, Imagination_image_penguin_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4336.801758), ('duration', 0.0), ('description', '0, Perception_image_flower_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4340.288086), ('duration', 0.0), ('description', '0, Imagination_image_flower_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4346.134766), ('duration', 0.0), ('description', '0, Perception_t_guitar_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4349.583984), ('duration', 0.0), ('description', '0, Imagination_t_guitar_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4354.332031), ('duration', 0.0), ('description', '0, Perception_t_penguin_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4357.826172), ('duration', 0.0), ('description', '0, Imagination_t_penguin_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4362.579102), ('duration', 0.0), ('description', '0, Perception_t_guitar_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4366.041016), ('duration', 0.0), ('description', '0, Imagination_t_guitar_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4370.806641), ('duration', 0.0), ('description', '0, Perception_t_guitar_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4374.299805), ('duration', 0.0), ('description', '0, Imagination_t_guitar_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4379.070312), ('duration', 0.0), ('description', '0, Perception_t_penguin_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4382.551758), ('duration', 0.0), ('description', '0, Imagination_t_penguin_3###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4388.175781), ('duration', 0.0), ('description', '0, Perceptiona_flower_low_17###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4391.076172), ('duration', 0.0), ('description', '0, Imagination_a_flower_low_17###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4396.060547), ('duration', 0.0), ('description', '0, Perceptiona_penguin_low_10###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4399.063477), ('duration', 0.0), ('description', '0, Imagination_a_penguin_low_10###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4404.043945), ('duration', 0.0), ('description', '0, Perceptiona_flower_low_23###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4407.047852), ('duration', 0.0), ('description', '0, Imagination_a_flower_low_23###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4412.037109), ('duration', 0.0), ('description', '0, Perceptiona_penguin_high_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4415.030273), ('duration', 0.0), ('description', '0, Imagination_a_penguin_high_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4420.020508), ('duration', 0.0), ('description', '0, Perceptiona_penguin_normal_25###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4423.022461), ('duration', 0.0), ('description', '0, Imagination_a_penguin_normal_25###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4429.322266), ('duration', 0.0), ('description', '0, Perception_image_guitar_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4432.762695), ('duration', 0.0), ('description', '0, Imagination_image_guitar_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4437.53418), ('duration', 0.0), ('description', '0, Perception_image_penguin_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4441.019531), ('duration', 0.0), ('description', '0, Imagination_image_penguin_m###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4445.777344), ('duration', 0.0), ('description', '0, Perception_image_flower_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4449.251953), ('duration', 0.0), ('description', '0, Imagination_image_flower_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4454.021484), ('duration', 0.0), ('description', '0, Perception_image_guitar_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4457.494141), ('duration', 0.0), ('description', '0, Imagination_image_guitar_c###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4462.25), ('duration', 0.0), ('description', '0, Perception_image_flower_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4465.725586), ('duration', 0.0), ('description', '0, Imagination_image_flower_s###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4471.383789), ('duration', 0.0), ('description', '0, Perceptiona_flower_high_23###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4474.291992), ('duration', 0.0), ('description', '0, Imagination_a_flower_high_23###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4479.270508), ('duration', 0.0), ('description', '0, Perceptiona_guitar_normal_25###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4482.273438), ('duration', 0.0), ('description', '0, Imagination_a_guitar_normal_25###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4487.262695), ('duration', 0.0), ('description', '0, Perceptiona_guitar_high_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4490.259766), ('duration', 0.0), ('description', '0, Imagination_a_guitar_high_5###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4495.262695), ('duration', 0.0), ('description', '0, Perceptiona_flower_high_23###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4498.266602), ('duration', 0.0), ('description', '0, Imagination_a_flower_high_23###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4503.25293), ('duration', 0.0), ('description', '0, Perceptiona_penguin_normal_10###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4506.25), ('duration', 0.0), ('description', '0, Imagination_a_penguin_normal_10###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4512.535156), ('duration', 0.0), ('description', '0, Perception_t_penguin_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4515.975586), ('duration', 0.0), ('description', '0, Imagination_t_penguin_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4520.735352), ('duration', 0.0), ('description', '0, Perception_t_flower_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4524.216797), ('duration', 0.0), ('description', '0, Imagination_t_flower_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4528.975586), ('duration', 0.0), ('description', '0, Perception_t_guitar_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4532.448242), ('duration', 0.0), ('description', '0, Imagination_t_guitar_1###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4537.198242), ('duration', 0.0), ('description', '0, Perception_t_flower_2###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4540.69043), ('duration', 0.0), ('description', '0, Imagination_t_flower_2###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4545.445312), ('duration', 0.0), ('description', '0, Perception_t_penguin_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4548.921875), ('duration', 0.0), ('description', '0, Imagination_t_penguin_4###my_stream_name'), ('orig_time', None)])
# OrderedDict([('onset', 4606.029297), ('duration', 0.0), ('description', '0, Impedance'), ('orig_time', None)])

# %%
events = mne.events_from_annotations(data)
eventId = {f'Imagination': list(range(1, 101)), f'Perception': list(range(101, 200))}
# Out:
# Used Annotations descriptions: ['0, Imagination_a_flower_high_10###my_stream_name', '0, Imagination_a_flower_high_11###my_stream_name', '0, Imagination_a_flower_high_17###my_stream_name', '0, Imagination_a_flower_high_23###my_stream_name', '0, Imagination_a_flower_high_4###my_stream_name', '0, Imagination_a_flower_high_5###my_stream_name', '0, Imagination_a_flower_low_10###my_stream_name', '0, Imagination_a_flower_low_13###my_stream_name', '0, Imagination_a_flower_low_17###my_stream_name', '0, Imagination_a_flower_low_23###my_stream_name', '0, Imagination_a_flower_low_25###my_stream_name', '0, Imagination_a_flower_low_5###my_stream_name', '0, Imagination_a_flower_normal_10###my_stream_name', '0, Imagination_a_flower_normal_11###my_stream_name', '0, Imagination_a_flower_normal_12###my_stream_name', '0, Imagination_a_flower_normal_16###my_stream_name', '0, Imagination_a_flower_normal_17###my_stream_name', '0, Imagination_a_flower_normal_19###my_stream_name', '0, Imagination_a_flower_normal_21###my_stream_name', '0, Imagination_a_flower_normal_22###my_stream_name', '0, Imagination_a_flower_normal_23###my_stream_name', '0, Imagination_a_flower_normal_24###my_stream_name', '0, Imagination_a_flower_normal_3###my_stream_name', '0, Imagination_a_flower_normal_5###my_stream_name', '0, Imagination_a_flower_normal_6###my_stream_name', '0, Imagination_a_guitar_high_11###my_stream_name', '0, Imagination_a_guitar_high_14###my_stream_name', '0, Imagination_a_guitar_high_18###my_stream_name', '0, Imagination_a_guitar_high_19###my_stream_name', '0, Imagination_a_guitar_high_25###my_stream_name', '0, Imagination_a_guitar_high_5###my_stream_name', '0, Imagination_a_guitar_low_10###my_stream_name', '0, Imagination_a_guitar_low_17###my_stream_name', '0, Imagination_a_guitar_low_19###my_stream_name', '0, Imagination_a_guitar_low_25###my_stream_name', '0, Imagination_a_guitar_low_3###my_stream_name', '0, Imagination_a_guitar_low_6###my_stream_name', '0, Imagination_a_guitar_normal_1###my_stream_name', '0, Imagination_a_guitar_normal_10###my_stream_name', '0, Imagination_a_guitar_normal_11###my_stream_name', '0, Imagination_a_guitar_normal_12###my_stream_name', '0, Imagination_a_guitar_normal_14###my_stream_name', '0, Imagination_a_guitar_normal_17###my_stream_name', '0, Imagination_a_guitar_normal_18###my_stream_name', '0, Imagination_a_guitar_normal_19###my_stream_name', '0, Imagination_a_guitar_normal_22###my_stream_name', '0, Imagination_a_guitar_normal_25###my_stream_name', '0, Imagination_a_guitar_normal_3###my_stream_name', '0, Imagination_a_guitar_normal_6###my_stream_name', '0, Imagination_a_guitar_normal_9###my_stream_name', '0, Imagination_a_penguin_high_10###my_stream_name', '0, Imagination_a_penguin_high_12###my_stream_name', '0, Imagination_a_penguin_high_25###my_stream_name', '0, Imagination_a_penguin_high_5###my_stream_name', '0, Imagination_a_penguin_high_6###my_stream_name', '0, Imagination_a_penguin_high_9###my_stream_name', '0, Imagination_a_penguin_low_10###my_stream_name', '0, Imagination_a_penguin_low_15###my_stream_name', '0, Imagination_a_penguin_low_19###my_stream_name', '0, Imagination_a_penguin_low_22###my_stream_name', '0, Imagination_a_penguin_low_25###my_stream_name', '0, Imagination_a_penguin_low_6###my_stream_name', '0, Imagination_a_penguin_normal_1 ###my_stream_name', '0, Imagination_a_penguin_normal_10###my_stream_name', '0, Imagination_a_penguin_normal_11###my_stream_name', '0, Imagination_a_penguin_normal_15###my_stream_name', '0, Imagination_a_penguin_normal_16###my_stream_name', '0, Imagination_a_penguin_normal_19###my_stream_name', '0, Imagination_a_penguin_normal_25###my_stream_name', '0, Imagination_a_penguin_normal_3###my_stream_name', '0, Imagination_a_penguin_normal_4###my_stream_name', '0, Imagination_a_penguin_normal_5###my_stream_name', '0, Imagination_a_penguin_normal_6###my_stream_name', '0, Imagination_a_penguin_normal_9###my_stream_name', '0, Imagination_audio_a_guitar_normal_10###my_stream_name',  ...

# %%
mappedEvents = []
for event in events[0]:
    if event[2] in eventId['Imagination']:
        mappedEvents.append([event[0], event[1], 1])
    elif event[2] in eventId['Perception']:
        mappedEvents.append([event[0], event[1], 2])
mappedEvents = np.array(mappedEvents)

# %%
mappedEvents
# Out:
# array([[      0,       0,       1],
#        [ 111127,       0,       2],
#        [ 114662,       0,       1],
#        ...,
#        [4654536,       0,       2],
#        [4658096,       0,       1],
#        [4716574,       0,       1]])

# %%
newEventId = {'Perception':2, 'Imagination':1}
epochs = mne.Epochs(data.copy(), mappedEvents[2:], event_id=newEventId, tmin=-0.2, tmax=1.0)
# Out:
# Not setting metadata
# 900 matching events found
# Setting baseline interval to [-0.2001953125, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated

# %%
perception = epochs['Perception'].average()
imagination = epochs['Imagination'].average()
# Out:
# (<Evoked | 'Perception' (average, N=449), -0.2002 – 1 s, baseline -0.200195 – 0 s, 124 ch, ~1.3 MB>,
#  <Evoked | 'Imagination' (average, N=450), -0.2002 – 1 s, baseline -0.200195 – 0 s, 124 ch, ~1.3 MB>)

# %%
perImage = perception.plot()
imagImage = imagination.plot()

# %%
perImage.savefig('Perception.png', dpi=600)
imagImage.savefig('imagination.png', dpi=600)

# %%
# Find peak amplitude and latency for each condition
peak1, latency1 = perception.get_peak(tmin=0, tmax=0.5, return_amplitude=True)
peak2, latency2 = imagination.get_peak(tmin=0, tmax=0.5, return_amplitude=True)

# Print peak amplitude and latency
print(f"Peak amplitude for eventType1: {peak1} uV at latency {latency1} seconds")
print(f"Peak amplitude for eventType2: {peak2} uV at latency {latency2} seconds")

# Calculate amplitude difference
amplitude_difference = peak1 - peak2
print(f"Amplitude difference between eventType1 and eventType2: {amplitude_difference} uV")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[86], line 2
#       1 # Find peak amplitude and latency for each condition
# ----> 2 peak1, latency1 = perception.get_peak(tmin=0, tmax=0.5, return_amplitude=True)
#       3 peak2, latency2 = imagination.get_peak(tmin=0, tmax=0.5, return_amplitude=True)
#       5 # Print peak amplitude and latency
#
# ValueError: too many values to unpack (expected 2)

# %%
from scipy import stats

# Extract data for statistical comparison
data1 = perception.data.squeeze()  # Squeeze removes unnecessary dimensions
data2 = imagination.data.squeeze()

# Perform paired t-test
t_statistic, p_value = stats.ttest_rel(data1, data2)

print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")

# Interpret the results
alpha = 0.05
if p_value < alpha:
    print("There is a significant difference between eventType1 and eventType2.")
else:
    print("No significant difference found between eventType1 and eventType2.")
# Out:
# T-statistic: [ 1.23415308e-08 -1.83279689e-08  1.55391431e-08 ... -8.84099878e-09
#   1.17892023e-08  9.77417031e-09]
# P-value: [0.99999999 0.99999999 0.99999999 ... 0.99999999 0.99999999 0.99999999]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[87], line 15
#      13 # Interpret the results
#      14 alpha = 0.05
# ---> 15 if p_value < alpha:
#      16     print("There is a significant difference between eventType1 and eventType2.")
#      17 else:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
epochs['Perception'].plot_image(picks=[15])
# Out:
# Using data from preloaded Raw for 449 events and 1230 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 449 matching events found
# No baseline correction applied
# 0 projection items activated
# [<Figure size 640x480 with 4 Axes>]

# %%
epochs['Imagination'].plot_image(picks=[13])
# Out:
# Using data from preloaded Raw for 451 events and 1230 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 450 matching events found
# No baseline correction applied
# 0 projection items activated
# [<Figure size 640x480 with 4 Axes>]

# %%
epochs.equalize_event_counts(newEventId)
# Out:
# Using data from preloaded Raw for 900 events and 1230 original time points ...
# 1 bad epochs dropped
# Dropped 1 epoch: 0
# (<Epochs |  898 events (all good), -0.200195 – 1 s, baseline -0.200195 – 0 s, ~173 kB, data not loaded,
#   'Perception': 449
#   'Imagination': 449>,
#  array([0], dtype=int64))

# %%
imagination.plot_joint([0.1,  0.3, 0.5, 0.7]);
# Out:
# No projector specified for this dataset. Please consider the method self.add_proj.

# %%
perception.plot_topomap();
# Out:
# <MNEFigure size 600x220 with 5 Axes>

# %%
import matplotlib.pyplot as plt

# Generate the plot using plot_joint()
fig = imagination.plot_joint([0.2, 0.4, 0.6, 0.8])

# Customize text properties for each axis
for ax in fig.axes:
    ax.xaxis.label.set_fontsize(12)
    ax.yaxis.label.set_fontsize(12)
    ax.xaxis.label.set_color('blue')
    ax.yaxis.label.set_color('green')
    ax.title.set_fontsize(5)
    ax.title.set_color('black')
    ax.tick_params(axis='both', which='major', labelsize=10, labelcolor='gray')

# Show the customized plot
plt.show()
# Out:
# No projector specified for this dataset. Please consider the method self.add_proj.

# %%
diff = mne.combine_evoked((imagination, - perception), weights='equal')
diff.plot_joint(times = [0.2,0.4, 0.6, 0.8]);
# Out:
# No projector specified for this dataset. Please consider the method self.add_proj.

# %%
diff.plot_image();

# %%
triggersTimestamps = data[0][1]['time_stamps']
triggers = data[0][1]['time_series']
len(triggersTimestamps), len(triggers)
# Out:
# (5322, 5322)

# %%
audio = data[0][3]['time_series']
audioTimestamps = data[0][3]['time_stamps']
eegData = data[0][2]['time_series']
eegTimestamps = data[0][2]['time_stamps']
audio.shape, audioTimestamps.shape, eegData.shape
# Out:
# ((183075840, 1), (183075840,), (3814127, 64))

# %%
triggers = np.array(triggers)
audio = audio.reshape(-1)
triggers = triggers.reshape(-1)
triggers.shape, audio.shape
# Out:
# ((5322,), (183075840,))

# %%
def getActivity(activity):
    if 'Fixation' in activity:
        return 'Fixation'
    elif 'ITI' in activity:
        return 'ITI'
    elif 'ISI' in activity:
        return 'ISI'
    elif 'Speech' in activity:
        return 'Speech'
    elif 'Stimulus' in activity:
        return 'Stimulus'
    else:
        return 'None'

# %%
triggers[:20]
# Out:
# array(['SilentSyllablesPracticeStartFixation:Text_silence',
#        'SilentSyllablesPracticeEndFixation:Text_silence',
#        'SilentSyllablesPracticeStartStimulus:Text_silence',
#        'SilentSyllablesPracticeEndStimulus:Text_silence',
#        'SilentSyllablesPracticeStartISI:Text_silence',
#        'SilentSyllablesPracticeEndISI:Text_silence',
#        'SilentSyllablesPracticeStartSpeech:Text_silence',
#        'SilentSyllablesPracticeEndSpeech:Text_silence',
#        'SilentSyllablesPracticeStartITI:Text_silence',
#        'SilentSyllablesPracticeEndITI:Text_silence',
#        'SilentSyllablesPracticeStartFixation:Audio_CLO',
#        'SilentSyllablesPracticeEndFixation:Audio_CLO',
#        'SilentSyllablesPracticeStartStimulus:Audio_CLO',
#        'SilentSyllablesPracticeEndStimulus:Audio_CLO',
#        'SilentSyllablesPracticeStartISI:Audio_CLO',
#        'SilentSyllablesPracticeEndISI:Audio_CLO',
#        'SilentSyllablesPracticeStartSpeech:Audio_CLO',
#        'SilentSyllablesPracticeEndSpeech:Audio_CLO',
#        'SilentSyllablesPracticeStartITI:Audio_CLO',
#        'SilentSyllablesPracticeEndITI:Audio_CLO'], dtype='<U55')

# %%
def findClosestIndex(timepoints, target):
   
    timepoints = np.asarray(timepoints)  # Ensure the input is a NumPy array
    idx = np.searchsorted(timepoints, target, side="left")
    if idx == 0:
        return 0
    if idx == len(timepoints):
        return len(timepoints) - 1
    
    before = idx - 1
    after = idx
    
    if after < len(timepoints) and abs(timepoints[after] - target) < abs(timepoints[before] - target):
        return after, timepoints[before]
    else:
        return before, timepoints[after]

# %%
activity = None
task = None
word = None
mappings = []
for index in range(0, triggers.shape[0], 2):
    activity, action = triggers[index].split(':')
    task, word = action.split('_')
    activity = getActivity(activity)
    markerStartTime = triggersTimestamps[index]
    markerEndTime = triggersTimestamps[index+1]
    audioStartIndex, audioStartTime = findClosestIndex(audioTimestamps, markerStartTime)
    audioEndIndex, audioEndTime = findClosestIndex(audioTimestamps, markerEndTime)
    eegStartIndex, eegStartTime = findClosestIndex(eegTimestamps, markerStartTime)
    eegEndIndex, eegEndTime = findClosestIndex(eegTimestamps, markerEndTime)
    mappings.append([activity, task, word,
                    markerStartTime, markerEndTime,
                    eegStartTime, eegEndTime, eegStartIndex, eegEndIndex,
                    audioStartTime, audioEndTime, audioStartIndex, audioEndIndex     
                ])

# %%
eegSamplingFrequency = data[0][2]['info']['nominal_srate'][0]
audioSamplingFrequency = data[0][3]['info']['nominal_srate'][0]
audioSamplingFrequency
# Out:
# '48000.00000000000'

# %%
import os
from pathlib import Path
dataDir = Path(os.getcwd(), 'PilotData')

os.makedirs(dataDir, exist_ok=True)

# %%
import json
from scipy.io.wavfile import write

# %%
for index in range(len(mappings)):
    activity, task, word,
    activity, task, word, markerStartTime, markerEndTime, eegStartTime, eegEndTime, eegStartIndex, eegEndIndex, audioStartTime, audioEndTime, audioStartIndex, audioEndIndex = mappings[index] 
    filename = f'{activity}_{task}_{word}_{index}'
    audioFilenamPath = Path(dataDir, f'{filename}.wav')
    eegDataFilenamePath = Path(dataDir,f'{filename}.npy')
    jsonFilenamePath = Path(dataDir, f'{filename}.json')

    eegSample = eegData[eegStartIndex:eegEndIndex, ]
    audioSample =audio[audioStartIndex:audioEndIndex]
    
    jsonMetaData = {}
    jsonMetaData['Activity'] = activity
    jsonMetaData['task'] = task
    jsonMetaData['word'] = word
    jsonMetaData['MarkerStartTime'] = markerStartTime
    jsonMetaData['MarkerEndTime'] = markerEndTime
    jsonMetaData['EegStartTime'] = eegStartTime
    jsonMetaData['EegEndTime'] = eegEndTime
    jsonMetaData['EegStartIndex'] = str(eegStartIndex)
    jsonMetaData['EegEndIndex'] = str(eegEndIndex)
    jsonMetaData['audioStartTime'] = audioStartTime
    jsonMetaData['audioEndTime'] = audioEndTime
    jsonMetaData['audioStartIndex'] = str(audioStartIndex)
    jsonMetaData['audioEndIndex'] = str(audioEndIndex)
    jsonMetaData['EEGSamplingFrequency'] = eegSamplingFrequency
    jsonMetaData['AudioSamplingFrequency'] = audioSamplingFrequency

    with open(jsonFilenamePath, 'w') as jsonFile:
        json.dump(jsonMetaData, jsonFile, indent=4)
    np.save(eegDataFilenamePath, eegSample)
    write(audioFilenamPath, 48000, audioSample)

# %%
write('audio.wav', 48000, audio)
